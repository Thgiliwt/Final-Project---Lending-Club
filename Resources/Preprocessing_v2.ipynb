# %%
import pandas as pd

# %%
df1 = pd.read_csv('cleaned_loan.csv',index_col=False)

df1
# Out:
#        loan_amnt  int_rate  installment  emp_length  annual_inc  loan_status  \
# 0          30000     22.35      1151.16           5   100000.00            1
# 1          40000     16.14       975.71           0    45000.00            1
# 2          20000      7.56       622.68          10   100000.00            1
# 3           4500     11.31       147.99          10    38500.00            1
# 4           8425     27.27       345.18           3   450000.00            1
# ...          ...       ...          ...         ...         ...          ...
# 47002      27950     17.09       997.75           9   235000.00            1
# 47003      30000     17.09      1070.93           6    88000.00            1
# 47004      18000     14.08       615.90           0    44000.00            0
# 47005      12000     12.62       270.71          10    89625.39            1
# 47006      14000     13.59       475.71           2    80000.00            1
#
# ...

# %%
df2 = df1[['loan_amnt','int_rate','emp_length','annual_inc','loan_status','term','home_ownership','purpose']]

df2
# Out:
#        loan_amnt  int_rate  emp_length  annual_inc  loan_status  term  \
# 0          30000     22.35           5   100000.00            1     0
# 1          40000     16.14           0    45000.00            1     1
# 2          20000      7.56          10   100000.00            1     0
# 3           4500     11.31          10    38500.00            1     0
# 4           8425     27.27           3   450000.00            1     0
# ...          ...       ...         ...         ...          ...   ...
# 47002      27950     17.09           9   235000.00            1     0
# 47003      30000     17.09           6    88000.00            1     0
# 47004      18000     14.08           0    44000.00            0     0
# 47005      12000     12.62          10    89625.39            1     1
# 47006      14000     13.59           2    80000.00            1     0
#
#        home_ownership  purpose
# 0                   1        2
# 1                   1        1
# ...

# %%
df2.to_csv('cleaned_loan.csv',index=False)
